# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

import pandas as pd
import numpy as np

# %%
fpath1 = 'roster_and_stats_merged.csv'
fpath2 = 'league_stats.csv'

allstar_df = pd.read_csv(fpath1)
allstar_df

league_df = pd.read_csv(fpath2)
league_df
# Out:
#       Unnamed: 0        Player Name  Shortname  Year  Age   ERA   ERA+     K%  \
# 0            736        Austin Voth   vothau01  2019   27  3.30  134.0  0.253
# 1            737       Wander Suero  suerowa01  2019   27  4.54   97.0  0.274
# 2            738  Stephen Strasburg  strasst01  2019   30  3.32  133.0  0.299
# 3            739          Tony Sipp   sippto01  2019   35  4.71   95.0  0.196
# 4            740       Max Scherzer  scherma01  2019   34  2.92  151.0  0.351
# ...          ...                ...        ...   ...  ...   ...    ...    ...
# 3076        4592   Jonathan Broxton  broxtjo01  2015   31  4.62   86.0  0.245
# 3077        4593       Aaron Brooks  brookaa01  2015   25  6.67   60.0  0.152
# 3078        4594       Matthew Boyd   boydma01  2015   24  7.53   54.0  0.171
# 3079        4595        Joe Blanton  blantjo01  2015   34  2.84  143.0  0.256
# 3080        4596        Luis Avilan  avilalu01  2015   25  4.05   95.0  0.223
#
#         BB%
# 0     0.075
# 1     0.088
# 2     0.067
# 3     0.098
# 4     0.048
# ...     ...
# 3076  0.086
# 3077  0.056
# 3078  0.079
# 3079  0.052
# 3080  0.068
#
# [3081 rows x 9 columns]

# %%
allstar_year_group = allstar_df.groupby('Year')
allstar_year_mean = allstar_year_group.mean()
allstar_year_df = pd.DataFrame(allstar_year_mean)
allstar_year_df = allstar_year_df.reset_index()
allstar_year_df
# Out:
#    Year  Unnamed: 0        Age       ERA        ERA+        K%       BB%
# 0  2015       137.0  28.000000  2.558929  171.464286  0.266857  0.068929
# 1  2016       105.5  28.970588  2.735000  178.176471  0.279765  0.073353
# 2  2017        74.0  28.655172  2.822759  174.310345  0.301276  0.073138
# 3  2018        44.5  28.833333  2.650333  175.733333  0.313533  0.072467
# 4  2019        14.5  28.866667  2.889333  166.466667  0.301300  0.066000

# %%
league_year_group = league_df.groupby('Year')
league_year_mean = league_year_group.mean()
league_year_df = pd.DataFrame(league_year_mean)
league_year_df = league_year_df.reset_index()
league_year_df
# Out:
#    Year   Unnamed: 0        Age       ERA        ERA+        K%       BB%
# 0  2015  4234.953177  28.056856  4.398278  108.919732  0.200978  0.084224
# 1  2016  3495.301003  27.884615  4.813110  108.411371  0.207579  0.088719
# 2  2017  2747.110553  28.072027  5.010771  108.788945  0.213794  0.090838
# 3  2018  1967.502355  27.908948  5.057928  105.285714  0.217251  0.093046
# 4  2019  1152.420891  27.890937  5.214332  107.499232  0.227104  0.097349

# %%
a = 'Year'
b = 'ERA+'

labels_year = league_year_df[a].tolist()
star_ERA = allstar_year_df[b].tolist()
league_ERA = league_year_df[b].tolist()


x = np.arange(len(labels_year))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, star_ERA, width, label=f'All Star {b}')
rects2 = ax.bar(x + width/2, league_ERA, width, label=f'League {b}')

plt.legend()
plt.xticks(np.arange(5), labels=labels_year)
plt.title(f'All Star vs. League in Average {b} by Year')
plt.xlabel(f'{a}')
plt.ylabel(f'{b}')
plt.ylim((0,200))

plt.show()
plt.savefig('Images/Allstar_vs_League_ERA+.png',dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = 'Year'
b = 'K%'

labels_year = league_year_df[a].tolist()
star_K = allstar_year_df[b].tolist()
league_K = league_year_df[b].tolist()

x = np.arange(len(labels_year))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, star_K, width, label=f'All Star {b}')
rects2 = ax.bar(x + width/2, league_K, width, label=f'League {b}')

plt.legend()
plt.xticks(np.arange(5), labels=labels_year)
plt.title(f'All Star vs. League in Average {b} by Year')
plt.xlabel(f'{a}')
plt.ylabel(f'{b}')
plt.ylim((0,0.4))

plt.show()
plt.savefig('Images/Allstar_vs_League_K%.png',dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = 'Year'
b = 'BB%'

labels_year = league_year_df[a].tolist()
star_BB = allstar_year_df[b].tolist()
league_BB = league_year_df[b].tolist()

x = np.arange(len(labels_year))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, star_BB, width, label=f'All Star {b}')
rects2 = ax.bar(x + width/2, league_BB, width, label=f'League {b}')

plt.legend()
plt.xticks(np.arange(5), labels=labels_year)
plt.title(f'All Star vs. League in Average {b} by Year')
plt.xlabel(f'{a}')
plt.ylabel(f'{b}')
plt.ylim((0,0.4))

plt.show()
plt.savefig('Images/Allstar_vs_League_BB%.png',dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
full_merge_df = pd.DataFrame.merge(allstar_year_df,league_year_df, on = 'Year', suffixes = ('_allstar', '_league'))
full_merge_df
# DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False,
#                 sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
# Out:
#    Year  Unnamed: 0_allstar  Age_allstar  ERA_allstar  ERA+_allstar  \
# 0  2015               137.0    28.000000     2.558929    171.464286
# 1  2016               105.5    28.970588     2.735000    178.176471
# 2  2017                74.0    28.655172     2.822759    174.310345
# 3  2018                44.5    28.833333     2.650333    175.733333
# 4  2019                14.5    28.866667     2.889333    166.466667
#
#    K%_allstar  BB%_allstar  Unnamed: 0_league  Age_league  ERA_league  \
# 0    0.266857     0.068929        4234.953177   28.056856    4.398278
# 1    0.279765     0.073353        3495.301003   27.884615    4.813110
# 2    0.301276     0.073138        2747.110553   28.072027    5.010771
# 3    0.313533     0.072467        1967.502355   27.908948    5.057928
# 4    0.301300     0.066000        1152.420891   27.890937    5.214332
#
#    ERA+_league  K%_league  BB%_league
# 0   108.919732   0.200978    0.084224
# 1   108.411371   0.207579    0.088719
# 2   108.788945   0.213794    0.090838
# 3   105.285714   0.217251    0.093046
# 4   107.499232   0.227104    0.097349

# %%
data_merge_df = pd.DataFrame.merge(allstar_df,league_df, on = 'Year', suffixes = ('_allstar', '_league'))

ERAplus_df = data_merge_df[['Year','ERA+_allstar','ERA+_league']]
ERAplus_df
# Out:
#        Year  ERA+_allstar  ERA+_league
# 0      2019         147.0        134.0
# 1      2019         147.0         97.0
# 2      2019         147.0        133.0
# 3      2019         147.0         95.0
# 4      2019         147.0        151.0
# ...     ...           ...          ...
# 93622  2015         105.0         86.0
# 93623  2015         105.0         60.0
# 93624  2015         105.0         54.0
# 93625  2015         105.0        143.0
# 93626  2015         105.0         95.0
#
# [93627 rows x 3 columns]

# %%
# fig1,ax1 = plt.subplots()
# ax1.set_title('Reaction times at Baseball Batting Cage')
# ax1.set_ylabel('Reaction Time (ms)')
# ax1.boxplot(times)
# plt.show()

ERAplus_df.boxplot("ERA+_allstar", by="Year")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:title={'center':'ERA+_allstar'}, xlabel='Year'>

# %%
# import os
# os.makedirs("Images")
plt.savefig('Images/Allstar_ERA+_Boxplot.png',dpi=400)

# %%
cols = list(dimensions.columns)
cols_d = pd.DataFrame(cols)

# %%
dimensions = pd.read_csv('dimensions_dict.csv')
dimensions2 = dimensions.iloc[:,[1,2,3,4,5,6,7,11,26,12,14,16]]
cols2 = list(dimensions2.columns)
cols_d2 = pd.DataFrame(cols2)
cols_d2
# Out:
#                           0
# 0                  position
# 1             birth_country
# 2                    weight
# 3               birth_state
# 4   name_display_first_last
# 5                   college
# 6             height_inches
# 7                name_first
# 8                 name_last
# 9                 team_code
# 10              height_feet
# 11                team_full

# %%
dimensions3 = dimensions2.iloc[:,[4,2,10,6,1,3,11]]
dimensions3.head()
# Out:
#   name_display_first_last  weight  height_feet  height_inches birth_country  \
# 0            Shane Bieber     200            6              3           USA
# 1         Aroldis Chapman     218            6              4          Cuba
# 2             Gerrit Cole     220            6              4           USA
# 3           Lucas Giolito     245            6              6           USA
# 4            Shane Greene     200            6              4           USA
#
#   birth_state          team_full
# 0          CA  Cleveland Indians
# 1         NaN   New York Yankees
# 2          CA   New York Yankees
# 3          CA  Chicago White Sox
# 4          FL     Atlanta Braves

# %%
height_df = dimensions3.copy()
height_df['height'] = height_df['height_feet']*12+height_df['height_inches']
height_df = height_df.rename(columns={"name_display_first_last": "Player Name"})
height_df = height_df.iloc[:,[0,1,7]]
height_df
# Out:
#          Player Name  weight  height
# 0       Shane Bieber     200      75
# 1    Aroldis Chapman     218      76
# 2        Gerrit Cole     220      76
# 3      Lucas Giolito     245      78
# 4       Shane Greene     200      76
# ..               ...     ...     ...
# 140   Kelvin Herrera     220      70
# 141     Darren O'Day     220      76
# 142      David Price     215      77
# 143       Chris Sale     183      78
# 144  Hector Santiago     215      72
#
# [145 rows x 3 columns]

# %%
allstar_df.head()
# Out:
#    Unnamed: 0  Year      Player Name  Shortname   Age   ERA   ERA+     K%  \
# 0           0  2019     Shane Bieber  biebesh01  24.0  3.28  147.0  0.302
# 1           1  2019  Aroldis Chapman  chapmar01  31.0  2.21  206.0  0.362
# 2           2  2019      Gerrit Cole   colege01  28.0  2.50  185.0  0.399
# 3           3  2019    Lucas Giolito  giolilu01  24.0  3.41  134.0  0.323
# 4           4  2019     Shane Greene  greensh02  30.0  2.30  207.0  0.254
#
#      BB%
# 0  0.047
# 1  0.106
# 2  0.059
# 3  0.081
# 4  0.068

# %%
merge_dim = pd.merge(height_df,allstar_df,left_on='Player Name', right_on='Player Name',how ='left')
merge_dim
# Out:
#          Player Name  weight  height  Unnamed: 0    Year  Shortname   Age  \
# 0       Shane Bieber     200      75         0.0  2019.0  biebesh01  24.0
# 1    Aroldis Chapman     218      76         1.0  2019.0  chapmar01  31.0
# 2    Aroldis Chapman     218      76        48.0  2018.0  chapmar01  30.0
# 3    Aroldis Chapman     218      76       127.0  2015.0  chapmar01  27.0
# 4        Gerrit Cole     220      76         2.0  2019.0   colege01  28.0
# ..               ...     ...     ...         ...     ...        ...   ...
# 280       Chris Sale     183      78        45.0  2018.0   salech01  29.0
# 281       Chris Sale     183      78        73.0  2017.0   salech01  28.0
# 282       Chris Sale     183      78        89.0  2016.0   salech01  27.0
# 283       Chris Sale     183      78       150.0  2015.0   salech01  26.0
# 284  Hector Santiago     215      72       151.0  2015.0  santihe01  27.0
#
#       ERA   ERA+     K%    BB%
# 0    3.28  147.0  0.302  0.047
# 1    2.21  206.0  0.362  0.106
# 2    2.45  172.0  0.439  0.142
# 3    1.63  244.0  0.417  0.119
# 4    2.50  185.0  0.399  0.059
# ..    ...    ...    ...    ...
# 280  2.11  209.0  0.384  0.055
# 281  2.90  157.0  0.362  0.051
# 282  3.34  121.0  0.257  0.050
# 283  3.41  114.0  0.321  0.049
# 284  3.59  105.0  0.209  0.092
#
# [285 rows x 11 columns]

# %%
merge_dim = merge_dim.drop_duplicates()
merge_dim = merge_dim.dropna()
merge_dim
# Out:
#          Player Name  weight  height  Unnamed: 0    Year  Shortname   Age  \
# 0       Shane Bieber     200      75         0.0  2019.0  biebesh01  24.0
# 1    Aroldis Chapman     218      76         1.0  2019.0  chapmar01  31.0
# 2    Aroldis Chapman     218      76        48.0  2018.0  chapmar01  30.0
# 3    Aroldis Chapman     218      76       127.0  2015.0  chapmar01  27.0
# 4        Gerrit Cole     220      76         2.0  2019.0   colege01  28.0
# ..               ...     ...     ...         ...     ...        ...   ...
# 267   Brad Boxberger     211      70       141.0  2015.0  boxbebr01  27.0
# 275  Felix Hernandez     220      75       145.0  2015.0  hernafe02  29.0
# 278     Darren O'Day     220      76       147.0  2015.0   odayda01  32.0
# 279      David Price     215      77       149.0  2015.0  priceda01  29.0
# 284  Hector Santiago     215      72       151.0  2015.0  santihe01  27.0
#
#       ERA   ERA+     K%    BB%
# 0    3.28  147.0  0.302  0.047
# 1    2.21  206.0  0.362  0.106
# 2    2.45  172.0  0.439  0.142
# 3    1.63  244.0  0.417  0.119
# 4    2.50  185.0  0.399  0.059
# ..    ...    ...    ...    ...
# 267  3.71  105.0  0.273  0.118
# 275  3.53  108.0  0.231  0.070
# 278  1.52  272.0  0.319  0.055
# 279  2.45  164.0  0.253  0.053
# 284  3.59  105.0  0.209  0.092
#
# [144 rows x 11 columns]

# %%
ht_2019 = merge_dim.loc[merge_dim['Year'] == 2019,:]
ht_2019.loc[merge_dim['Player Name'] == 'Max Scherzer',:]
# Out:
#      Player Name  weight  height  Unnamed: 0    Year  Shortname   Age   ERA  \
# 40  Max Scherzer     208      75        23.0  2019.0  scherma01  34.0  2.92
#
#      ERA+     K%    BB%
# 40  151.0  0.351  0.048

# %%
from scipy.stats import linregress

x_values = ht_2019['height']
y_values = ht_2019['ERA+']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(72,250),fontsize=15,color="red")
# Out:
# Text(72, 250, 'y = -7x + 677.47')

# %%
ht_2018 = merge_dim.loc[merge_dim['Year'] == 2018,:]
x_values = ht_2018['height']
y_values = ht_2018['ERA+']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(72,250),fontsize=15,color="red")
# Out:
# Text(72, 250, 'y = 2x + 12.94')

# %%
ht_2017 = merge_dim.loc[merge_dim['Year'] == 2017,:]
x_values = ht_2017['height']
y_values = ht_2017['ERA+']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(72,250),fontsize=15,color="red")
# Out:
# Text(72, 250, 'y = 8x + -456.63')

# %%
ht_2016 = merge_dim.loc[merge_dim['Year'] == 2016,:]
x_values = ht_2016['height']
y_values = ht_2016['ERA+']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(72,250),fontsize=15,color="red")
# Out:
# Text(72, 250, 'y = 1x + 133.32')
